# %%
# Check GPU availability and CUDA version
# !nvidia-smi
# !nvcc --version

# Import necessary modules
import os

# Set the current working directory
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# Thu Aug 21 20:04:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   36C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# HOME: /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Installing Cellpose version 3

# %%
# !pip install cellpose==3.1.1.1

# !pip install optuna
# Out:
# Collecting cellpose==3.1.1.1
#   Downloading cellpose-3.1.1.1-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy<2.1,>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (1.16.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (2025.6.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (4.67.1)
# Requirement already satisfied: numba>=0.53.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (0.60.0)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (0.43.0)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (2.8.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose==3.1.1.1) (4.12.0.88)
# Collecting fastremap (from cellpose==3.1.1.1)
#   Downloading fastremap-1.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting imagecodecs (from cellpose==3.1.1.1)
#   Downloading imagecodecs-2025.8.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting roifile (from cellpose==3.1.1.1)
#   Downloading roifile-2025.5.10-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.1.1.1) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6->cellpose==3.1.1.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6->cellpose==3.1.1.1) (3.0.2)
# Downloading cellpose-3.1.1.1-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.9/225.9 kB 10.2 MB/s eta 0:00:00
# Downloading fastremap-1.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 107.7 MB/s eta 0:00:00
# Downloading imagecodecs-2025.8.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 84.3 MB/s eta 0:00:00
# Downloading roifile-2025.5.10-py3-none-any.whl (17 kB)
# Installing collected packages: roifile, imagecodecs, fastremap, cellpose
# Successfully installed cellpose-3.1.1.1 fastremap-1.17.2 imagecodecs-2025.8.2 roifile-2025.5.10
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 15.3 MB/s eta 0:00:00
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 24.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.4 colorlog-6.9.0 optuna-4.5.0

# %% [markdown]
# ## Input batches

# %%
a_input_folders = ['/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_input/1. PSD95/1. Original File Names/',
                '/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_input/2. SY38/1. Original File Names/',
               '/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_input/3. MXO4/1. Original File Names/',
               '/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_input/4. GFAP/1. Original File Names/'
               ]


a_gt_folders = [
            '/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_output/1. PSD95/2. Decrypted File Names/',
            '/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_output/2. SY38/2. Decrypted File Names/',
            '/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_output/3. MXO4/2. Decrypted File Names/',
            '/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_output/4. GFAP/2. Decrypted File Names/']

b_input_folders = ['/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_input/1. PSD95/1. Original File Names/',
                '/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_input/2. SY38/1. Original File Names/',
               '/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_input/3. MXO4/1. Original File Names/',
               '/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_input/4. GFAP/1. Original File Names/'
               ]


b_gt_folders = [
            '/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_output/1. PSD95/2. Decrypted File Names/',
            '/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_output/2. SY38/2. Decrypted File Names/',
            '/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_output/3. MXO4/2. Decrypted File Names/',
            '/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_output/4. GFAP/2. Decrypted File Names/']

# %% [markdown]
# ## Pretrained model paths

# %%
psd_model_paths = ['/content/drive/MyDrive/Colab Notebooks/models/Cellpose/PSD_train_test_same_batch_501_tune',
'/content/drive/MyDrive/Colab Notebooks/models/Cellpose/PSD_train_test_diff_batch_501_tune',
'/content/drive/MyDrive/Colab Notebooks/models/Cellpose/PSD_train_test_mixed_batch_501_tune']


sy38_model_paths = ['/content/drive/MyDrive/Colab Notebooks/models/Cellpose/SY38_train_test_same_batch_501',
'/content/drive/MyDrive/Colab Notebooks/models/Cellpose/SY38_train_test_diff_batch_501',
'/content/drive/MyDrive/Colab Notebooks/models/Cellpose/SY38_train_test_mixed_batch_501']

# %% [markdown]
# ## Re-tune and train example

# %%
command = f'python "/content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/model_scripts/cellpose_retraining.py" -mn PSD -tts 0.8 -mode train_test_same_batch \
 -input1 "{b_input_folders[0]}" -gt1 "{b_gt_folders[0]}" -input2 "{a_input_folders[0]}" -gt2 "{a_gt_folders[0]}" \
 -ts 0.3 -tunep 0.4 -trainp 0.5 -testp 0.6 -numt 2 -nume 99 -run_mode tune -model_path "{psd_model_paths[0]}"'

# !{command}
# Out:
# 2025-08-21 20:52:35,014 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2025-08-21 20:52:35,014 [INFO]
# cellpose version: 	3.1.1.1
# platform:       	linux
# python version: 	3.12.11
# torch version:  	2.8.0+cu126
# Namespace(model_name='PSD', train_test_split=0.8, train_test_mode='train_test_same_batch', input_folders_1='/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_input/1. PSD95/1. Original File Names/', gt_folders_1='/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_output/1. PSD95/2. Decrypted File Names/', input_folders_2='/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_input/1. PSD95/1. Original File Names/', gt_folders_2='/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_output/1. PSD95/2. Decrypted File Names/', tune_split=0.3, tune_indice_prop=0.4, train_indice_prop=0.5, test_indice_prop=0.6, num_tune_trials=2, num_epoch=99, run_mode='tune', pretrained_model_path='/content/drive/MyDrive/Colab Notebooks/models/Cellpose/PSD_train_test_same_batch_501_tune')
# Create train and test data by reading and formatting input files and applying train-test split
#
# /content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_input/1. PSD95/1. Original File Names/
#
# Create tune data
#
#
# Run hyperparameter tuning
#
# [I 2025-08-21 20:52:49,875] A new study created in memory with name: no-name-f81673ce-0c5c-4fba-b937-9e32768c6cba
# 2025-08-21 20:52:49,877 [INFO] >> nuclei << model set to be used
# 2025-08-21 20:52:49,877 [INFO] Downloading: "https://www.cellpose.org/models/nucleitorch_0" to /root/.cellpose/models/nucleitorch_0
#
# 100% 25.3M/25.3M [00:00<00:00, 33.4MB/s]
# 2025-08-21 20:52:51,002 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-21 20:52:51,002 [INFO] >>>> using GPU (CUDA)
# 2025-08-21 20:52:51,071 [INFO] >>>> loading model /root/.cellpose/models/nucleitorch_0
# 2025-08-21 20:52:51,153 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# 2025-08-21 20:52:51,153 [INFO] computing flows for labels
# 100% 42/42 [00:02<00:00, 14.68it/s]
# 2025-08-21 20:52:54,116 [INFO] computing flows for labels
# 100% 50/50 [00:01<00:00, 29.83it/s]
# 2025-08-21 20:52:55,908 [INFO] >>> computing diameters
# 100% 42/42 [00:00<00:00, 279.61it/s]
# 100% 50/50 [00:00<00:00, 284.55it/s]
# 2025-08-21 20:52:56,235 [INFO] >>> using channels [0, 0]
# 2025-08-21 20:52:56,495 [INFO] >>> n_epochs=50, n_train=42, n_test=50
# 2025-08-21 20:52:56,495 [INFO] >>> AdamW, learning_rate=0.02265, weight_decay=0.01772
# 2025-08-21 20:52:57,602 [INFO] >>> saving model to /content/models/optuna_trial_model
# 2025-08-21 20:52:59,132 [INFO] 0, train_loss=0.3606, test_loss=0.1472, LR=0.000000, time 1.53s
# 2025-08-21 20:53:02,198 [INFO] 5, train_loss=0.0975, test_loss=0.4793, LR=0.012585, time 4.60s
# 2025-08-21 20:53:05,307 [INFO] 10, train_loss=0.0779, test_loss=0.0780, LR=0.022653, time 7.71s
# 2025-08-21 20:53:10,839 [INFO] 20, train_loss=0.0678, test_loss=0.0807, LR=0.022653, time 13.24s
# 2025-08-21 20:53:16,376 [INFO] 30, train_loss=0.0716, test_loss=0.1451, LR=0.022653, time 18.77s
# 2025-08-21 20:53:21,877 [INFO] 40, train_loss=0.0708, test_loss=0.0799, LR=0.022653, time 24.28s
# 2025-08-21 20:53:26,256 [INFO] saving network parameters to /content/models/optuna_trial_model
# [I 2025-08-21 20:53:26,578] Trial 0 finished with value: 0.057292888313531874 and parameters: {'learning_rate': 0.02265331761649948, 'weight_decay': 0.01771610563254132, 'batch_size': 2, 'rescale': True, 'normalize': False, 'SGD': False, 'pretrained_model_name': 'nuclei'}. Best is trial 0 with value: 0.057292888313531874.
# 2025-08-21 20:53:26,748 [INFO] >> nuclei << model set to be used
# 2025-08-21 20:53:26,748 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-21 20:53:26,748 [INFO] >>>> using GPU (CUDA)
# 2025-08-21 20:53:26,817 [INFO] >>>> loading model /root/.cellpose/models/nucleitorch_0
# 2025-08-21 20:53:26,899 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# 2025-08-21 20:53:26,899 [INFO] computing flows for labels
# 100% 42/42 [00:01<00:00, 28.71it/s]
# 2025-08-21 20:53:28,463 [INFO] computing flows for labels
# 100% 50/50 [00:01<00:00, 29.08it/s]
# 2025-08-21 20:53:30,301 [INFO] >>> computing diameters
# 100% 42/42 [00:00<00:00, 283.86it/s]
# 100% 50/50 [00:00<00:00, 291.56it/s]
# 2025-08-21 20:53:30,621 [INFO] >>> using channels [0, 0]
# 2025-08-21 20:53:30,845 [INFO] >>> n_epochs=50, n_train=42, n_test=50
# 2025-08-21 20:53:30,845 [INFO] >>> AdamW, learning_rate=0.01282, weight_decay=0.00087
# 2025-08-21 20:53:30,846 [INFO] >>> saving model to /content/models/optuna_trial_model
# 2025-08-21 20:53:31,986 [INFO] 0, train_loss=0.3606, test_loss=0.1472, LR=0.000000, time 1.14s
# 2025-08-21 20:53:35,047 [INFO] 5, train_loss=0.0895, test_loss=0.0832, LR=0.007121, time 4.20s
# 2025-08-21 20:53:38,110 [INFO] 10, train_loss=0.0735, test_loss=0.0780, LR=0.012817, time 7.26s
# 2025-08-21 20:53:43,668 [INFO] 20, train_loss=0.0659, test_loss=0.0715, LR=0.012817, time 12.82s
# 2025-08-21 20:53:49,180 [INFO] 30, train_loss=0.0696, test_loss=0.0632, LR=0.012817, time 18.33s
# 2025-08-21 20:53:54,688 [INFO] 40, train_loss=0.0685, test_loss=0.0653, LR=0.012817, time 23.84s
# 2025-08-21 20:53:59,056 [INFO] saving network parameters to /content/models/optuna_trial_model
# [I 2025-08-21 20:53:59,396] Trial 1 finished with value: 0.05603940412402153 and parameters: {'learning_rate': 0.012817234523479208, 'weight_decay': 0.0008699732789798245, 'batch_size': 2, 'rescale': True, 'normalize': False, 'SGD': False, 'pretrained_model_name': 'nuclei'}. Best is trial 1 with value: 0.05603940412402153.
# Best trial:
#   Value: 0.05603940412402153
#   Params:
#     learning_rate: 0.012817234523479208
#     weight_decay: 0.0008699732789798245
#     batch_size: 2
#     rescale: True
#     normalize: False
#     SGD: False
#     pretrained_model_name: nuclei
#
# Run training
#
# 2025-08-21 20:53:59,564 [INFO] >> nuclei << model set to be used
# 2025-08-21 20:53:59,564 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-21 20:53:59,564 [INFO] >>>> using GPU (CUDA)
# 2025-08-21 20:53:59,629 [INFO] >>>> loading model /root/.cellpose/models/nucleitorch_0
# 2025-08-21 20:53:59,713 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# 2025-08-21 20:53:59,713 [INFO] computing flows for labels
# 100% 220/220 [00:07<00:00, 28.00it/s]
# 2025-08-21 20:54:08,090 [INFO] computing flows for labels
# 100% 50/50 [00:01<00:00, 26.75it/s]
# 2025-08-21 20:54:10,076 [INFO] >>> computing diameters
# 100% 220/220 [00:00<00:00, 287.06it/s]
# 100% 50/50 [00:00<00:00, 290.65it/s]
# 2025-08-21 20:54:11,015 [INFO] >>> using channels [0, 0]
# 2025-08-21 20:54:11,744 [INFO] >>> n_epochs=99, n_train=220, n_test=50
# 2025-08-21 20:54:11,745 [INFO] >>> AdamW, learning_rate=0.01282, weight_decay=0.00087
# 2025-08-21 20:54:11,746 [INFO] >>> saving model to /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/models/Cellpose/PSD_train_test_same_batch_99_tune
# 2025-08-21 20:54:13,386 [INFO] 0, train_loss=0.3238, test_loss=0.1293, LR=0.000000, time 1.64s
# 2025-08-21 20:54:18,921 [INFO] 5, train_loss=0.0812, test_loss=0.0722, LR=0.007121, time 7.18s
# 2025-08-21 20:54:24,338 [INFO] 10, train_loss=0.0777, test_loss=0.0690, LR=0.012817, time 12.59s
# 2025-08-21 20:54:34,820 [INFO] 20, train_loss=0.0739, test_loss=0.0919, LR=0.012817, time 23.07s
# 2025-08-21 20:54:45,157 [INFO] 30, train_loss=0.0673, test_loss=0.0667, LR=0.012817, time 33.41s
# 2025-08-21 20:54:55,468 [INFO] 40, train_loss=0.0662, test_loss=0.0635, LR=0.012817, time 43.72s
# 2025-08-21 20:55:05,852 [INFO] 50, train_loss=0.0693, test_loss=0.0658, LR=0.012817, time 54.11s
# 2025-08-21 20:55:16,163 [INFO] 60, train_loss=0.0656, test_loss=0.0769, LR=0.012817, time 64.42s
# 2025-08-21 20:55:26,586 [INFO] 70, train_loss=0.0662, test_loss=0.0673, LR=0.012817, time 74.84s
# 2025-08-21 20:55:37,004 [INFO] 80, train_loss=0.0655, test_loss=0.0944, LR=0.012817, time 85.26s
# 2025-08-21 20:55:47,391 [INFO] 90, train_loss=0.0665, test_loss=0.0713, LR=0.012817, time 95.65s
# 2025-08-21 20:55:55,175 [INFO] saving network parameters to /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/models/Cellpose/PSD_train_test_same_batch_99_tune
# Model path saved from training
# /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/models/Cellpose/PSD_train_test_same_batch_99_tune
# Save model details
# Model details saved to: /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/results/Model_details/Cellpose_PSD_train_test_same_batch_99_tune.json
#
# Run evaluation
#
# Loading trained model
# 2025-08-21 20:55:56,429 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-21 20:55:56,429 [INFO] >>>> using GPU (CUDA)
# 2025-08-21 20:55:56,495 [INFO] >>>> loading model /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/models/Cellpose/PSD_train_test_same_batch_99_tune
# 2025-08-21 20:55:56,598 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# 2025-08-21 20:55:56,598 [INFO] >>>> model diam_labels =  5.000 (mean diameter of training ROIs)
# Running PSD/SY38 eval
# 2025-08-21 20:55:56,598 [INFO] 0%|          | 0/116 [00:00<?, ?it/s]
# 2025-08-21 20:56:29,170 [INFO] 8%|7         | 9/116 [00:32<06:27,  3.62s/it]
# 2025-08-21 20:56:40,216 [INFO] 8%|7         | 9/116 [00:43<06:27,  3.62s/it]
# 2025-08-21 20:57:02,512 [INFO] 16%|#5        | 18/116 [01:05<05:59,  3.67s/it]
# 2025-08-21 20:57:20,217 [INFO] 16%|#5        | 18/116 [01:23<05:59,  3.67s/it]
# 2025-08-21 20:57:35,194 [INFO] 24%|##4       | 28/116 [01:38<05:05,  3.48s/it]
# 2025-08-21 20:57:50,218 [INFO] 24%|##4       | 28/116 [01:53<05:05,  3.48s/it]
# 2025-08-21 20:58:08,069 [INFO] 34%|###3      | 39/116 [02:11<04:11,  3.27s/it]
# 2025-08-21 20:58:20,219 [INFO] 34%|###3      | 39/116 [02:23<04:11,  3.27s/it]
# 2025-08-21 20:58:40,865 [INFO] 43%|####3     | 50/116 [02:44<03:28,  3.16s/it]
# 2025-08-21 20:59:00,220 [INFO] 43%|####3     | 50/116 [03:03<03:28,  3.16s/it]
# 2025-08-21 20:59:13,129 [INFO] 51%|#####     | 59/116 [03:16<03:07,  3.29s/it]
# 2025-08-21 20:59:30,221 [INFO] 51%|#####     | 59/116 [03:33<03:07,  3.29s/it]
# 2025-08-21 20:59:46,030 [INFO] 59%|#####8    | 68/116 [03:49<02:43,  3.40s/it]
# 2025-08-21 21:00:00,221 [INFO] 59%|#####8    | 68/116 [04:03<02:43,  3.40s/it]
# 2025-08-21 21:00:17,101 [INFO] 66%|######6   | 77/116 [04:20<02:13,  3.42s/it]
# 2025-08-21 21:00:30,222 [INFO] 66%|######6   | 77/116 [04:33<02:13,  3.42s/it]
# 2025-08-21 21:00:48,351 [INFO] 74%|#######4  | 86/116 [04:51<01:43,  3.43s/it]
# 2025-08-21 21:01:00,223 [INFO] 74%|#######4  | 86/116 [05:03<01:43,  3.43s/it]
# 2025-08-21 21:01:19,130 [INFO] 82%|########1 | 95/116 [05:22<01:12,  3.43s/it]
# 2025-08-21 21:01:30,224 [INFO] 82%|########1 | 95/116 [05:33<01:12,  3.43s/it]
# 2025-08-21 21:01:50,852 [INFO] 91%|######### | 105/116 [05:54<00:36,  3.35s/it]
# 2025-08-21 21:02:10,225 [INFO] 91%|######### | 105/116 [06:13<00:36,  3.35s/it]
# 2025-08-21 21:02:21,133 [INFO] 99%|#########9| 115/116 [06:24<00:03,  3.25s/it]
# 2025-08-21 21:02:24,136 [INFO] 100%|##########| 116/116 [06:27<00:00,  3.34s/it]
#
# Determine resulting performance
#
# /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/model_scripts/cellpose_retraining.py:176: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row_df], ignore_index=True)
#
# Save example masks
#
#                                            File name  ... high_performance_score
# 81         PF390-S2-Stack-C-CROPPED-psd.tif_image_15  ...               0.397213
# 108  PF415-S1-Stack-B-Plaque-CROPPED-psd.tif_image_2  ...               0.460957
# 74          PF390-S2-Stack-C-CROPPED-psd.tif_image_8  ...               0.371937
#
# [3 rows x 9 columns]
#                                            File name  ... low_performance_score
# 81         PF390-S2-Stack-C-CROPPED-psd.tif_image_15  ...              0.729143
# 108  PF415-S1-Stack-B-Plaque-CROPPED-psd.tif_image_2  ...              0.740048
# 74          PF390-S2-Stack-C-CROPPED-psd.tif_image_8  ...              0.741256
#
# [3 rows x 10 columns]
# HPM: [81, 108, 74]
# LPM: [102, 99, 96]
#
# Create image directory if it doesn't already exist
# Run overal post-processing and save summary results
# /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/model_scripts/cellpose_retraining.py:176: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row_df], ignore_index=True)

# %% [markdown]
# ## Load retrained model example

# %%
command = f'python "/content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/model_scripts/cellpose_retraining.py" -mn PSD -tts 0.8 -mode train_test_same_batch \
 -input1 "{b_input_folders[0]}" -gt1 "{b_gt_folders[0]}" -input2 "{a_input_folders[0]}" -gt2 "{a_gt_folders[0]}" \
 -ts 0.3 -tunep 1 -trainp 1 -testp 0.5 -numt 2 -nume 99 -run_mode eval -model_path "{psd_model_paths[0]}"'

# !{command}
# Out:
# 2025-08-21 20:20:11,865 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2025-08-21 20:20:11,865 [INFO]
# cellpose version: 	3.1.1.1
# platform:       	linux
# python version: 	3.12.11
# torch version:  	2.8.0+cu126
# Namespace(model_name='PSD', train_test_split=0.8, train_test_mode='train_test_same_batch', input_folders_1='/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_input/1. PSD95/1. Original File Names/', gt_folders_1='/content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_output/1. PSD95/2. Decrypted File Names/', input_folders_2='/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_input/1. PSD95/1. Original File Names/', gt_folders_2='/content/drive/MyDrive/Colab Notebooks/Lab_images/Colab_data/Segmentation_output/1. PSD95/2. Decrypted File Names/', tune_split=0.3, tune_indice_prop=1.0, train_indice_prop=1.0, test_indice_prop=0.5, num_tune_trials=2, num_epoch=99, run_mode='eval', pretrained_model_path='/content/drive/MyDrive/Colab Notebooks/models/Cellpose/PSD_train_test_same_batch_501_tune')
# Create train and test data by reading and formatting input files and applying train-test split
#
# /content/drive/MyDrive/Colab Notebooks/Lab_images/Batch_B/Segmentation_input/1. PSD95/1. Original File Names/
#
# Skipping training and loading pretrained model
# Loading model /content/drive/MyDrive/Colab Notebooks/models/Cellpose/PSD_train_test_same_batch_501_tune
# /content/drive/MyDrive/Colab Notebooks/models/Cellpose/PSD_train_test_same_batch_501_tune
#
# Run evaluation
#
# Loading trained model
# 2025-08-21 20:20:26,920 [WARNING] pretrained_model path does not exist, using default model
# 2025-08-21 20:20:26,920 [INFO] Downloading: "https://www.cellpose.org/models/cyto3" to /root/.cellpose/models/cyto3
#
# 100% 25.3M/25.3M [00:00<00:00, 32.7MB/s]
# 2025-08-21 20:20:28,044 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-21 20:20:28,044 [INFO] >>>> using GPU (CUDA)
# 2025-08-21 20:20:28,114 [INFO] >>>> loading model /root/.cellpose/models/cyto3
# 2025-08-21 20:20:28,195 [INFO] >>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)
# Running PSD/SY38 eval
# 2025-08-21 20:20:28,195 [INFO] 0%|          | 0/194 [00:00<?, ?it/s]
# 2025-08-21 20:20:59,229 [INFO] 9%|8         | 17/194 [00:31<05:23,  1.83s/it]
# 2025-08-21 20:21:17,231 [INFO] 9%|8         | 17/194 [00:49<05:23,  1.83s/it]
# 2025-08-21 20:21:30,107 [INFO] 20%|#9        | 38/194 [01:01<04:09,  1.60s/it]
# 2025-08-21 20:21:47,232 [INFO] 20%|#9        | 38/194 [01:19<04:09,  1.60s/it]
# 2025-08-21 20:22:00,458 [INFO] 30%|###       | 59/194 [01:32<03:25,  1.53s/it]
# 2025-08-21 20:22:17,233 [INFO] 30%|###       | 59/194 [01:49<03:25,  1.53s/it]
# 2025-08-21 20:22:31,291 [INFO] 40%|####      | 78/194 [02:03<03:01,  1.56s/it]
# 2025-08-21 20:22:47,234 [INFO] 40%|####      | 78/194 [02:19<03:01,  1.56s/it]
# 2025-08-21 20:23:01,767 [INFO] 50%|#####     | 97/194 [02:33<02:32,  1.58s/it]
# 2025-08-21 20:23:17,235 [INFO] 50%|#####     | 97/194 [02:49<02:32,  1.58s/it]
# 2025-08-21 20:23:32,227 [INFO] 61%|######1   | 119/194 [03:04<01:52,  1.51s/it]
# 2025-08-21 20:23:47,236 [INFO] 61%|######1   | 119/194 [03:19<01:52,  1.51s/it]
# 2025-08-21 20:24:03,482 [INFO] 72%|#######2  | 140/194 [03:35<01:21,  1.50s/it]
# 2025-08-21 20:24:17,237 [INFO] 72%|#######2  | 140/194 [03:49<01:21,  1.50s/it]
# 2025-08-21 20:24:34,713 [INFO] 83%|########2 | 161/194 [04:06<00:49,  1.50s/it]
# 2025-08-21 20:24:47,238 [INFO] 83%|########2 | 161/194 [04:19<00:49,  1.50s/it]
# 2025-08-21 20:25:05,457 [INFO] 96%|#########5| 186/194 [04:37<00:11,  1.40s/it]
# 2025-08-21 20:25:14,984 [INFO] 100%|##########| 194/194 [04:46<00:00,  1.48s/it]
#
# Determine resulting performance
#
# /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/model_scripts/cellpose_retraining.py:176: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row_df], ignore_index=True)
#
# Save example masks
#
#                                            File name  ... high_performance_score
# 101  PF415-S1-Stack-A-Plaque-CROPPED-psd.tif_image_6  ...               0.414048
# 24          PF390-S2-Stack-A-CROPPED-psd.tif_image_2  ...               0.622537
# 54          PF390-S2-Stack-B-CROPPED-psd.tif_image_2  ...               0.239988
#
# [3 rows x 9 columns]
#                                            File name  ... low_performance_score
# 101  PF415-S1-Stack-A-Plaque-CROPPED-psd.tif_image_6  ...              0.917176
# 24          PF390-S2-Stack-A-CROPPED-psd.tif_image_2  ...              0.922668
# 54          PF390-S2-Stack-B-CROPPED-psd.tif_image_2  ...              0.924277
#
# [3 rows x 10 columns]
# HPM: [101, 24, 54]
# LPM: [138, 137, 51]
#
# Create image directory if it doesn't already exist
# Run overal post-processing and save summary results
# /content/drive/MyDrive/Colab Notebooks/Segmentation_Pipeline/model_scripts/cellpose_retraining.py:176: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row_df], ignore_index=True)
